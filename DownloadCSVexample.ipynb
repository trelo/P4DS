# %% [markdown]
# ## Download CSV example

# %%
import pandas as pd
BWHistSample = pd.io.parsers.read_csv("Blackwell_Hist_Sample.csv")
print(BWHistSample)
# Out:
#       in.store  age  items   amount  region
# 0            0   60      8  2103.80       3
# 1            1   58      4   968.38       3
# 2            0   51      7   143.59       2
# 3            1   40      7   863.82       3
# 4            0   41      4   915.21       1
# 5            0   79      6   426.17       2
# 6            0   79      1   471.43       2
# 7            0   31      3   115.52       2
# 8            0   29      6   129.25       4
# 9            1   25      6  1025.90       1
# 10           0   57      2  1384.70       3
# 11           0   55      6   352.82       2
# 12           0   58      1   450.41       2
# 13           0   73      5   416.93       2
# 14           0   60      3   638.38       3
# 15           1   35      4  1740.10       4
# 16           1   32      4  1308.30       1
# 17           1   50      4   749.37       3
# 18           1   25      4  1854.80       4
# 19           1   48      8   707.09       1
# ...
